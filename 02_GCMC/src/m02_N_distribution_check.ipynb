# %% [markdown]
# ## M(N_sites)の分布をチェック

# %%
from c01_gcmc_states import GCMCState


N_history = []

for step in range(n_steps):
    gcmc.step()
    if step > equilibration:
        N_history.append(gcmc.state.N_ads)
